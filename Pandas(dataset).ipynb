# %%
# importing the libraries
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\hi\\Documents\\Artificial Intelligence'

# %%
a=pd.read_csv(r"C:\Users\hi\Downloads\matches2008-2016.csv")

# %%
print(a.head())
# Out:
#   match_id  season        city        date team1_id team2_id toss_winner  \
# 0   2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1   2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2   2008_3    2008       Delhi  19-04-2008       RR       DD          RR
# 3   2008_4    2008      Mumbai  20-04-2008       MI      RCB          MI
# 4   2008_5    2008     Kolkata  20-04-2008       DC      KKR          DC
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    KKR          140               0
# 1           bat  normal           0    CSK           33               0
# 2           bat  normal           0     DD            0               9
# 3           bat  normal           0    RCB            0               5
# 4           bat  normal           0    KKR            0               5
#
#     player_of_match  player_of_match_id  \
# 0  Brendon McCullum                82.0
# ...

# %%
print(a.tail())
# Out:
#     match_id  season       city        date team1_id team2_id toss_winner  \
# 572  2016_56    2016     Raipur  22-05-2016       DD      RCB         RCB
# 573  2016_57    2016  Bangalore  24-05-2016       GL      RCB         RCB
# 574  2016_58    2016      Delhi  25-05-2016      SRH      KKR         KKR
# 575  2016_59    2016      Delhi  27-05-2016       GL      SRH         SRH
# 576  2016_60    2016  Bangalore  29-05-2016      SRH      RCB         SRH
#
#     toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 572         field  normal           0    RCB            0               6
# 573         field  normal           0    RCB            0               4
# 574         field  normal           0    SRH           22               0
# 575         field  normal           0    SRH            0               4
# 576           bat  normal           0    SRH            8               0
#
#       player_of_match  player_of_match_id  \
# ...

# %%
a.shape
# Out:
# (577, 19)

# %%
a.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'team1_id', 'team2_id',
#        'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner',
#        'win_by_runs', 'win_by_wickets', 'player_of_match',
#        'player_of_match_id', 'venue', 'venue_id', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
a.dtypes
# Out:
# match_id               object
# season                  int64
# city                   object
# date                   object
# team1_id               object
# team2_id               object
# toss_winner            object
# toss_decision          object
# result                 object
# dl_applied              int64
# winner                 object
# win_by_runs             int64
# win_by_wickets          int64
# player_of_match        object
# player_of_match_id    float64
# venue                  object
# venue_id                int64
# umpire1                object
# umpire2                object
# dtype: object

# %%
a.ndim
# Out:
# 2

# %%
a.size
# Out:
# 10963

# %%
a.isna
# Out:
# <bound method DataFrame.isna of     match_id  season        city        date team1_id team2_id toss_winner  \
# 0     2008_1    2008   Bangalore  18-04-2008      KKR      RCB         RCB
# 1     2008_2    2008  Chandigarh  19-04-2008      CSK      KXI         CSK
# 2     2008_3    2008       Delhi  19-04-2008       RR       DD          RR
# 3     2008_4    2008      Mumbai  20-04-2008       MI      RCB          MI
# 4     2008_5    2008     Kolkata  20-04-2008       DC      KKR          DC
# ..       ...     ...         ...         ...      ...      ...         ...
# 572  2016_56    2016      Raipur  22-05-2016       DD      RCB         RCB
# 573  2016_57    2016   Bangalore  24-05-2016       GL      RCB         RCB
# 574  2016_58    2016       Delhi  25-05-2016      SRH      KKR         KKR
# 575  2016_59    2016       Delhi  27-05-2016       GL      SRH         SRH
# 576  2016_60    2016   Bangalore  29-05-2016      SRH      RCB         SRH
#
# ...

# %%
a.isna()
# Out:
#      match_id  season   city   date  team1_id  team2_id  toss_winner  \
# 0       False   False  False  False     False     False        False
# 1       False   False  False  False     False     False        False
# 2       False   False  False  False     False     False        False
# 3       False   False  False  False     False     False        False
# 4       False   False  False  False     False     False        False
# ..        ...     ...    ...    ...       ...       ...          ...
# 572     False   False  False  False     False     False        False
# 573     False   False  False  False     False     False        False
# 574     False   False  False  False     False     False        False
# 575     False   False  False  False     False     False        False
# 576     False   False  False  False     False     False        False
#
#      toss_decision  result  dl_applied  winner  win_by_runs  win_by_wickets  \
# ...

# %%
a.isna().any()
# Out:
# match_id              False
# season                False
# city                   True
# date                  False
# team1_id              False
# team2_id              False
# toss_winner           False
# toss_decision         False
# result                False
# dl_applied            False
# winner                 True
# win_by_runs           False
# win_by_wickets        False
# player_of_match        True
# player_of_match_id     True
# venue                 False
# venue_id              False
# umpire1               False
# umpire2               False
# dtype: bool

# %%
a.isna().sum()
# Out:
# match_id              0
# season                0
# city                  7
# date                  0
# team1_id              0
# team2_id              0
# toss_winner           0
# toss_decision         0
# result                0
# dl_applied            0
# winner                3
# win_by_runs           0
# win_by_wickets        0
# player_of_match       3
# player_of_match_id    3
# venue                 0
# venue_id              0
# umpire1               0
# umpire2               0
# dtype: int64

# %%
a.shape
# Out:
# (577, 18)

# %%
del a['winner']

# %%
del a['player_of_match']

# %%
del a['player_of_match_id']

# %%
a.shape
# Out:
# (577, 15)

# %%
print(a.head())
# Out:
#   match_id  season        date team1_id team2_id toss_winner toss_decision  \
# 0   2008_1    2008  18-04-2008      KKR      RCB         RCB         field
# 1   2008_2    2008  19-04-2008      CSK      KXI         CSK           bat
# 2   2008_3    2008  19-04-2008       RR       DD          RR           bat
# 3   2008_4    2008  20-04-2008       MI      RCB          MI           bat
# 4   2008_5    2008  20-04-2008       DC      KKR          DC           bat
#
#    result  dl_applied  win_by_runs  win_by_wickets  \
# 0  normal           0          140               0
# 1  normal           0           33               0
# 2  normal           0            0               9
# 3  normal           0            0               5
# 4  normal           0            0               5
#
#                                                venue  venue_id    umpire1  \
# 0         M.Chinnaswamy Stadium Bengaluru, Karnataka         7  Asad Rauf
# ...

# %%
a.isna().any()
# Out:
# match_id          False
# season            False
# date              False
# team1_id          False
# team2_id          False
# toss_winner       False
# toss_decision     False
# result            False
# dl_applied        False
# win_by_runs       False
# win_by_wickets    False
# venue             False
# venue_id          False
# umpire1           False
# umpire2           False
# dtype: bool

# %%
a.axes
# Out:
# [RangeIndex(start=0, stop=577, step=1),
#  Index(['match_id', 'season', 'date', 'team1_id', 'team2_id', 'toss_winner',
#         'toss_decision', 'result', 'dl_applied', 'win_by_runs',
#         'win_by_wickets', 'venue', 'venue_id', 'umpire1', 'umpire2'],
#        dtype='object')]

# %%
a.values
# Out:
# array([['2008_1', 2008, '18-04-2008', ..., 7, 'Asad Rauf', 'RE Koertzen'],
#        ['2008_2', 2008, '19-04-2008', ..., 9, 'MR Benson', 'SL Shastri'],
#        ['2008_3', 2008, '19-04-2008', ..., 2, 'Aleem Dar',
#         'GA Pratapkumar'],
#        ...,
#        ['2016_58', 2016, '25-05-2016', ..., 2, 'M Erasmus',
#         'C Shamshuddin'],
#        ['2016_59', 2016, '27-05-2016', ..., 2, 'M Erasmus', 'CK Nandan'],
#        ['2016_60', 2016, '29-05-2016', ..., 7, 'HDPK Dharmasena',
#         'BNJ Oxenford']], dtype=object)

# %%
a.sum()
# Out:
# match_id          2008_12008_22008_32008_42008_52008_62008_72008...
# season                                                      1160941
# date              18-04-200819-04-200819-04-200820-04-200820-04-...
# team1_id          KKRCSKRRMIDCKXIDCCSKDCKXIRCBKKRMIDDCSKKKRDDDCR...
# team2_id          RCBKXIDDRCBKKRRRDDMIRRMIRRCSKDCKXIRCBMIRCBKXIK...
# toss_winner       RCBCSKRRMIDCKXIDCMIRRMIRRKKRDCDDCSKKKRRCBKXIRR...
# toss_decision     fieldbatbatbatbatbatbatfieldfieldfieldfieldbat...
# result            normalnormalnormalnormalnormalnormalnormalnorm...
# dl_applied                                                       15
# win_by_runs                                                    7914
# win_by_wickets                                                 1941
# venue             M.Chinnaswamy Stadium Bengaluru, KarnatakaI.S....
# venue_id                                                       5826
# umpire1           Asad RaufMR BensonAleem DarSJ DavisBF BowdenAl...
# ...

# %%
a.count()
# Out:
# match_id          577
# season            577
# date              577
# team1_id          577
# team2_id          577
# toss_winner       577
# toss_decision     577
# result            577
# dl_applied        577
# win_by_runs       577
# win_by_wickets    577
# venue             577
# venue_id          577
# umpire1           577
# umpire2           577
# dtype: int64

# %%
a.mean()
# Out:
# match_id                  inf
# season            2012.029463
# dl_applied           0.025997
# win_by_runs         13.715771
# win_by_wickets       3.363951
# venue_id            10.097054
# dtype: float64

# %%
a.std()
# Out:
# season             2.486247
# dl_applied         0.159263
# win_by_runs       23.619282
# win_by_wickets     3.416049
# venue_id           9.048535
# dtype: float64

# %%
a.median()
# Out:
# match_id          201169.0
# season              2012.0
# dl_applied             0.0
# win_by_runs            0.0
# win_by_wickets         3.0
# venue_id               7.0
# dtype: float64

# %%
a.dropna()
# Out:
#     match_id  season        date team1_id team2_id toss_winner toss_decision  \
# 0     2008_1    2008  18-04-2008      KKR      RCB         RCB         field
# 1     2008_2    2008  19-04-2008      CSK      KXI         CSK           bat
# 2     2008_3    2008  19-04-2008       RR       DD          RR           bat
# 3     2008_4    2008  20-04-2008       MI      RCB          MI           bat
# 4     2008_5    2008  20-04-2008       DC      KKR          DC           bat
# ..       ...     ...         ...      ...      ...         ...           ...
# 572  2016_56    2016  22-05-2016       DD      RCB         RCB         field
# 573  2016_57    2016  24-05-2016       GL      RCB         RCB         field
# 574  2016_58    2016  25-05-2016      SRH      KKR         KKR         field
# 575  2016_59    2016  27-05-2016       GL      SRH         SRH         field
# 576  2016_60    2016  29-05-2016      SRH      RCB         SRH           bat
#
# ...

# %%
a.dropna(how="all")
# Out:
#     match_id  season        date team1_id team2_id toss_winner toss_decision  \
# 0     2008_1    2008  18-04-2008      KKR      RCB         RCB         field
# 1     2008_2    2008  19-04-2008      CSK      KXI         CSK           bat
# 2     2008_3    2008  19-04-2008       RR       DD          RR           bat
# 3     2008_4    2008  20-04-2008       MI      RCB          MI           bat
# 4     2008_5    2008  20-04-2008       DC      KKR          DC           bat
# ..       ...     ...         ...      ...      ...         ...           ...
# 572  2016_56    2016  22-05-2016       DD      RCB         RCB         field
# 573  2016_57    2016  24-05-2016       GL      RCB         RCB         field
# 574  2016_58    2016  25-05-2016      SRH      KKR         KKR         field
# 575  2016_59    2016  27-05-2016       GL      SRH         SRH         field
# 576  2016_60    2016  29-05-2016      SRH      RCB         SRH           bat
#
# ...

# %%
a.dropna(axis=1)
# Out:
#     match_id  season        date team1_id team2_id toss_winner toss_decision  \
# 0     2008_1    2008  18-04-2008      KKR      RCB         RCB         field
# 1     2008_2    2008  19-04-2008      CSK      KXI         CSK           bat
# 2     2008_3    2008  19-04-2008       RR       DD          RR           bat
# 3     2008_4    2008  20-04-2008       MI      RCB          MI           bat
# 4     2008_5    2008  20-04-2008       DC      KKR          DC           bat
# ..       ...     ...         ...      ...      ...         ...           ...
# 572  2016_56    2016  22-05-2016       DD      RCB         RCB         field
# 573  2016_57    2016  24-05-2016       GL      RCB         RCB         field
# 574  2016_58    2016  25-05-2016      SRH      KKR         KKR         field
# 575  2016_59    2016  27-05-2016       GL      SRH         SRH         field
# 576  2016_60    2016  29-05-2016      SRH      RCB         SRH           bat
#
# ...

# %%
from statistics import mean,median,mode,variance

# %%
print(mean(a['season']))
# Out:
# 2012.0294627383016

# %%
print(median(a['dl_applied']))
# Out:
# 0

# %%
print(mode(a['win_by_runs']))
# Out:
# 0

# %%
print(variance(a['win_by_wickets']))
# Out:
# 11.6693926920855

# %%
b=a['win_by_runs']

# %%
b
# Out:
# 0      140
# 1       33
# 2        0
# 3        0
# 4        0
#       ...
# 572      0
# 573      0
# 574     22
# 575      0
# 576      8
# Name: win_by_runs, Length: 577, dtype: int64

# %%
b.max()
# Out:
# 144

# %%
b.min()
# Out:
# 0

# %%
b.cumsum()
# Out:
# 0       140
# 1       173
# 2       173
# 3       173
# 4       173
#        ...
# 572    7884
# 573    7884
# 574    7906
# 575    7906
# 576    7914
# Name: win_by_runs, Length: 577, dtype: int64

# %%
b.cumprod()
# Out:
# 0       140
# 1      4620
# 2         0
# 3         0
# 4         0
#        ...
# 572       0
# 573       0
# 574       0
# 575       0
# 576       0
# Name: win_by_runs, Length: 577, dtype: int64

# %%
b.count()
# Out:
# 577

# %%
a.T
# Out:
#                                                        0    \
# match_id                                            2008_1
# season                                                2008
# date                                            18-04-2008
# team1_id                                               KKR
# team2_id                                               RCB
# toss_winner                                            RCB
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# win_by_runs                                            140
# win_by_wickets                                           0
# venue           M.Chinnaswamy Stadium Bengaluru, Karnataka
# venue_id                                                 7
# umpire1                                          Asad Rauf
# umpire2                                        RE Koertzen
#
# ...

# %%
b.T
# Out:
# 0      140
# 1       33
# 2        0
# 3        0
# 4        0
#       ...
# 572      0
# 573      0
# 574     22
# 575      0
# 576      8
# Name: win_by_runs, Length: 577, dtype: int64
